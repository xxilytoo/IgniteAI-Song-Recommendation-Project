# %% [markdown]
# <a href="https://colab.research.google.com/github/xxilytoo/IgniteAI-Song-Recommendation-Project/blob/main/Link_Dataset_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("Database to calculate popularity.csv")
df.head()
# Out:
#    Unnamed: 0 country        date  position  \
# 0           0  Global  05/11/2020       1.0
# 1           1  Global  05/11/2020       2.0
# 2           2  Global  05/11/2020       3.0
# 3           3  Global  05/11/2020       4.0
# 4           4  Global  05/11/2020       5.0
#
#                                                  uri  \
# 0  https://open.spotify.com/track/47EiUVwUp4C9fGc...
# 1  https://open.spotify.com/track/35mvY5S1H3J2QZy...
# 2  https://open.spotify.com/track/3tjFYV6RSFtuktY...
# 3  https://open.spotify.com/track/7hxHWCCAIIxFLCz...
# 4  https://open.spotify.com/track/4y4spB9m0Q6026K...
#
#                                track        title                    artist
# 0   Dakiti , Bad Bunny, Jhay Cortez       Dakiti    Bad Bunny, Jhay Cortez
# 1         positions , Ariana Grande    positions             Ariana Grande
# 2                  Mood  , 24kGoldn        Mood                   24kGoldn
# ...

# %%
df = df[["uri","title"]]
df.head()
# Out:
#                                                  uri        title
# 0  https://open.spotify.com/track/47EiUVwUp4C9fGc...      Dakiti
# 1  https://open.spotify.com/track/35mvY5S1H3J2QZy...   positions
# 2  https://open.spotify.com/track/3tjFYV6RSFtuktY...       Mood
# 3  https://open.spotify.com/track/7hxHWCCAIIxFLCz...   Lemonade
# 4  https://open.spotify.com/track/4y4spB9m0Q6026K...     Lonely

# %%
df["title"] = df["title"].str.lower()
df.head()
# Out:
#                                                  uri        title
# 0  https://open.spotify.com/track/47EiUVwUp4C9fGc...      dakiti
# 1  https://open.spotify.com/track/35mvY5S1H3J2QZy...   positions
# 2  https://open.spotify.com/track/3tjFYV6RSFtuktY...       mood
# 3  https://open.spotify.com/track/7hxHWCCAIIxFLCz...   lemonade
# 4  https://open.spotify.com/track/4y4spB9m0Q6026K...     lonely

# %%
df.to_csv("songurls.csv")

# %%
df.tail()
# Out:
#                                                        uri          title
# 1731221  https://open.spotify.com/track/2ez6qvOTHKeI3ss...   trampoline
# 1731222  https://open.spotify.com/track/3Dv1eDb0MEgF93G...        say so
# 1731223  https://open.spotify.com/track/2Fxmhks0bxGSBdJ...       bad guy
# 1731224  https://open.spotify.com/track/16wAOAZ2OkqoIDN...         yummy
# 1731225  https://open.spotify.com/track/5yY9lUy8nbvjM1U...            NaN

# %%
from google.colab import files
files.download('songurls.csv')
